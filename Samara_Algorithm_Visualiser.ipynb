# %% [markdown]
# <a href="https://colab.research.google.com/github/SamaraRC/Algorithm-Visualiser/blob/main/Samara_Algorithm_Visualiser.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello world!")
# Out:
# Hello world!
